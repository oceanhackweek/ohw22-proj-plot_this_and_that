# %%
#Imports
import xarray as xr
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# Get data
SBE37_1 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/CTD_timeseries/IMOS_ANMN-QLD_CSTZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE37SMP-RS232-157_END-20220226T031500Z_C-20220523T221351Z.nc'
SBE37_2 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/CTD_timeseries/IMOS_ANMN-QLD_CSTZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE37SMP-RS232-303_END-20220226T031500Z_C-20220523T221348Z.nc'
SBE37_3 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/CTD_timeseries/IMOS_ANMN-QLD_CSTZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE37SMP-RS232-37_END-20220226T031500Z_C-20220523T221357Z.nc'

RBRsolo_1 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-RBRsolo-127_END-20220226T031500Z_C-20220523T221352Z.nc'
RBRsolo_2 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-RBRsolo-137_END-20220226T031500Z_C-20220523T221352Z.nc'
RBRsolo_3 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-RBRsolo-157_END-20220226T031500Z_C-20220523T221351Z.nc'
RBRsolo_4 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-RBRsolo-277_END-20220226T031500Z_C-20220523T221349Z.nc'
RBRsolo_5 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-RBRsolo-334_END-20220226T031500Z_C-20220523T221347Z.nc'

SBE39_1 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE39-197_END-20220226T031500Z_C-20220523T221350Z.nc'
SBE39_2 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE39-237_END-20220226T031500Z_C-20220523T221349Z.nc'
SBE39_3 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE39-338_END-20220226T031500Z_C-20220523T221345Z.nc'
SBE39_4 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE39-57_END-20220226T031500Z_C-20220523T221356Z.nc'
SBE39_5 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE39plus-117_END-20220226T031500Z_C-20220523T221353Z.nc'
SBE39_6 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE39plus-87_END-20220226T031500Z_C-20220523T221355Z.nc'

SBE56_1 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE56-107_END-20220226T031500Z_C-20220523T221354Z.nc'
SBE56_2 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE56-30_END-20220226T031500Z_C-20220523T221358Z.nc'
SBE56_3 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE56-47_END-20220226T031500Z_C-20220523T221357Z.nc'
SBE56_4 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE56-67_END-20220226T031500Z_C-20220523T221356Z.nc'
SBE56_5 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE56-77_END-20220226T031500Z_C-20220523T221355Z.nc'
SBE56_6 = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/QLD/GBRLSL/Temperature/IMOS_ANMN-QLD_TZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-SBE56-97_END-20220226T031500Z_C-20220523T221354Z.nc'

RDI_ADCP = 'http://thredds.aodn.org.au/thredds/dodsC/IMOS/ANMN/Velocity/IMOS_ANMN-QLD_AETVZ_20210824T042500Z_GBRLSL_FV01_GBRLSL-2108-Long-Ranger-Workhorse-ADCP-334_END-20220226T031500Z_C-20220523T221346Z.nc'

LSL2108_37s = [SBE37_1, SBE37_2, SBE37_3]
LSL2108_solos = [RBRsolo_1, RBRsolo_2, RBRsolo_3, RBRsolo_4, RBRsolo_5]
LSL2108_39s = [SBE39_1, SBE39_2, SBE39_3, SBE39_4, SBE39_5, SBE39_6]
LSL2108_56s = [SBE56_1, SBE56_2, SBE56_3, SBE56_4, SBE56_5, SBE56_6]
LSL2108_ADCP = [RDI_ADCP]
LSL2108_files = [LSL2108_37s, LSL2108_solos, LSL2108_39s, LSL2108_56s]

# %% [markdown]
# ## ADCP Data

# %%
# temp_fig = temp_file['TEMP'].plot()
Y = adcp_file['TIME']
X = adcp_file['HEIGHT_ABOVE_SENSOR']
Z = adcp_file['VCUR']
plt.contour(X, Y, Z, 40);

# %% [markdown]
# ## 56 Data

# %%
fig, axs = plt.subplots(6)
counter = 0
for file in LSL2108_56s:
    my_nc = xr.open_dataset(file)
    my_nc = my_nc.to_dataframe()
    my_nc = my_nc[my_nc.TEMP_quality_control == 1]
    # plt.plot(my_nc['TEMP'])
    axs[counter].plot(my_nc['TEMP'])
    counter += 1
fig.suptitle('LSL2108 56s')
# Out:
# Text(0.5, 0.98, 'LSL2108 56s')

# %%
# plot lines
for file in LSL2108_56s:
    my_nc = xr.open_dataset(file)
    my_nc = my_nc.to_dataframe()
    my_nc = my_nc[my_nc.TEMP_quality_control == 1]
    plt.plot(my_nc['TEMP'])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 37 Data

# %%
# LSL2108_37s[0]
fig, axs = plt.subplots(3)
for file in LSL2108_37s:
    my_nc = xr.open_dataset(file)
    my_nc = my_nc.to_dataframe()
    my_nc = my_nc[my_nc.TEMP_quality_control == 1]
    fig.suptitle('LSL2108 37s')
    axs[0].plot(my_nc['TEMP'])
    axs[1].plot(my_nc['PSAL'])
    axs[2].plot(my_nc['DEPTH'])
plt.legend()
plt.show()

# port hacking
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 39 Data

# %%
# my_nc['TEMP_quality_control'].head()
# LSL2108_39s[0]
fig, axs = plt.subplots(2)
for file in LSL2108_39s:
    my_nc = xr.open_dataset(file)
    my_nc = my_nc.to_dataframe()
    fig.suptitle('LSL2108 39s')
    my_nc = my_nc[my_nc.TEMP_quality_control == 1]
    axs[0].plot(my_nc['TEMP'])
    axs[1].plot(my_nc['DEPTH'])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
